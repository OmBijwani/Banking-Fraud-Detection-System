# %%
# IMPORT REQUIRED FUNCTIONS

from src.data_ingestion.load_data import load_data
from src.data_ingestion.validate_data import (
    check_missing_values,
    check_duplicates,
    check_required_columns
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 3
#       1 # IMPORT REQUIRED FUNCTIONS
#       2
# ----> 3 from src.data_ingestion.load_data import load_data
#       4 from src.data_ingestion.validate_data import (
#       5     check_missing_values,
#       6     check_duplicates,
#
# ModuleNotFoundError: No module named 'src'
